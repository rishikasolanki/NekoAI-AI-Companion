# %%
import pickle

with open(r'C:\Users\solan\OneDrive\Desktop\NekoAI\NekoAI-AI-Companion\ml_model\models\pipeline.pkl', 'rb') as f:
    X_train, X_test, y_train, y_test = pickle.load(f)

# %%
import pickle

with open(r'C:\Users\solan\OneDrive\Desktop\NekoAI\NekoAI-AI-Companion\ml_model\models\productivity_model.pkl', 'rb') as f:
    X_train, X_test, y_train, y_test = pickle.load(f)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)
import numpy as np

def evaluate_model(name, y_true, y_pred):

    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)

    print("="*40)
    print(name)
    print("="*40)
    print("MAE :", round(mae,3))
    print("MSE :", round(mse,3))
    print("RMSE:", round(rmse,3))
    print("R²  :", round(r2,3))

# %%
evaluate_model("Linear Regression", y_test, lr_pred)

evaluate_model("Decision Tree", y_test, dt_pred)

evaluate_model("Random Forest", y_test, rf_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #evaluate_model("Linear Regression", y_test, lr_pred)
#       2
# ----> 3 evaluate_model("Decision Tree", y_test, dt_pred)
#       4
#       5 evaluate_model("Random Forest", y_test, rf_pred)
#
# NameError: name 'dt_pred' is not defined
